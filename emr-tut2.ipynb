# %% [markdown]
# <a href="https://colab.research.google.com/github/ANKUM24/RuView/blob/main/emr-tut2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1
import sys
from datetime import datetime
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# %%
# Step 2
input_path = "tripdata.csv"
output_path = "output/"

# %%
# Step 3
spark = SparkSession.builder.appName("PySparkExample").getOrCreate()
nyTaxi = spark.read.option("inferSchema", "true").option("header", "true").csv(input_path)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipykernel_4652/3987129862.py in <cell line: 0>()
#       1 # Step 3
#       2 spark = SparkSession.builder.appName("PySparkExample").getOrCreate()
# ----> 3 nyTaxi = spark.read.option("inferSchema", "true").option("header", "true").csv(input_path)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
# ...

# %%
# Step 4
nyTaxi.count()

# %%
# Step 5
nyTaxi.show()

# %%
# Step 6
nyTaxi.printSchema()

# %%
# Step 7
updatedNYTaxi = nyTaxi.withColumn("current_date", lit(datetime.now()))

# %%
# Step 8
updatedNYTaxi.printSchema()
